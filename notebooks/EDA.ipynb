# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/concrete_data.csv")

# %%
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
df.shape
# Out:
# (1030, 9)

# %% [markdown]
# ## Understanding the dataset
# The actual concrete compressive strength (MPa) for a given mixture under a
# specific age (days) was determined fromthe  laboratory. Data is in raw form (not scaled).
# The datasett contains the 9 attributesWhich are given below
#
# Nam -- - Data Typ --- Measuremen
#
#
# *
#
# Cement (component 1) -- quantitative -- kg in a m3 mixt
#
# b* le
# Blast Furnace Slag (component 2) -- quantitative -- kg in a m3 mixta
#
# * ble
# Fly Ash (component 3) -- quantitative -- kg in a m3 mii
#
# * able
# Water (component 4) -- quantitative -- kg in a m3 mr
#
# * iable
# Superplasticizer (component 5) -- quantitative -- kg in a m3 a
#
# * riable
# Coarse Aggregate (component 6) -- quantitative -- kg in a m3V
#
# * ariable
# Fine Aggregate (component 7) -- quantitative -- kg in a m
#
# * Variable
# Age -- quantitative -- Day (1~365)
#
# Dependant feature
# Variable
#
# Concrete compressive strength -- quantitput Variable

# %%
## check for NAN values
df.isna().sum()
# Out:
# cement                           0
# blast_furnace_slag               0
# fly_ash                          0
# water                            0
# superplasticizer                 0
# coarse_aggregate                 0
# fine_aggregate                   0
# age                              0
# concrete_compressive_strength    0
# dtype: int64

# %%
## Check for duplicate values
df.duplicated().sum()
# Out:
# 25

# %% [markdown]
# ## Handel duplicate values
# in the the dataset we have 25 duplicate rows which needs to be handeled

# %%
## we will drop the duplicates
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1005, 9)

# %%
## check for column datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1005 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cement                         1005 non-null   float64
#  1   blast_furnace_slag             1005 non-null   float64
#  2   fly_ash                        1005 non-null   float64
#  3   water                          1005 non-null   float64
#  4   superplasticizer               1005 non-null   float64
#  5   coarse_aggregate               1005 non-null   float64
#  6   fine_aggregate                 1005 non-null   float64
#  7   age                            1005 non-null   int64
#  8   concrete_compressive_strength  1005 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 78.5 KB

# %%
## Checking for unique values in data frame columns
df.nunique()
# Out:
# cement                           278
# blast_furnace_slag               185
# fly_ash                          156
# water                            195
# superplasticizer                 111
# coarse_aggregate                 284
# fine_aggregate                   302
# age                               14
# concrete_compressive_strength    845
# dtype: int64

# %%
## Checking the statistic for data set
df.describe()
# Out:
#             cement  blast_furnace_slag      fly_ash        water  \
# count  1005.000000         1005.000000  1005.000000  1005.000000
# mean    278.631343           72.043483    55.536318   182.075323
# std     104.344261           86.170807    64.207969    21.339334
# min     102.000000            0.000000     0.000000   121.800000
# 25%     190.700000            0.000000     0.000000   166.600000
# 50%     265.000000           20.000000     0.000000   185.700000
# 75%     349.000000          142.500000   118.300000   192.900000
# max     540.000000          359.400000   200.100000   247.000000
#
#        superplasticizer  coarse_aggregate  fine_aggregate           age  \
# count       1005.000000       1005.000000      1005.000000  1005.000000
# mean           6.033234        974.376816       772.688259    45.856716
# std            5.919967         77.579667        80.340435    63.734692
# min            0.000000        801.000000       594.000000     1.000000
# ...

# %% [markdown]
# ## In the given dataset we have all quantity feature, Let's start with the data visualization

# %%
columns = df.columns

# %%
for i in columns:
    sns.histplot(df[i], kde=True)
    print()
    plt.show()

# %%
## correlation heatmap
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
## Scatter plot 
x = df['concrete_compressive_strength']
y = df['cement']

plt.scatter(x,y)
plt.show()
